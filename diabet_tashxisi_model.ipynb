# %% [markdown]
# ## Diabet kasalligi tashxisini qo'yuvchi Sun'iy Intellekt model yaratish loyihasi

# %% [markdown]
# ### Vazifa
# Quyidagi ma'lumotlar to'plami Hindistonning Qandli diabet va buyrak kasalliklari milliy institutidan olingan. Maqsad diagnostik o'lchovlar asosida bemorda diabet bor-yo'qligini taxmin qilishdir.
#
#
#  Ushbu vazifani CRSIP-DM metodologiyasi yordamida bajaramiz
# <img src="https://i.imgur.com/dzZnnYi.png" alt="CRISP-DM" width="800"/>

# %% [markdown]
# ### 1-qadam. Faoliyatni o'rganish
# *  Tibbiyotning ushbu soha mutaxassislari bilan muloqot qilib diabet kasalligi haqida yetarlicha bilim va tushunchalar olamiz
# *  Sohada qo'llaniladigan atama va tushunchalar haqida ma'lumotlar olamiz
# *  Mavjud muammo va qo'yilayotgan talablarga aniqlik kiritamiz
# *   Muammoga yechim berishda bir necha qismlardan iborat reja tuzamiz

# %% [markdown]
# ### 2-qadam. Ma'lumotlarni o'rganish

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_predict
from sklearn.metrics import f1_score, jaccard_score, confusion_matrix, classification_report

# %%
# Datasetni yuklab olamiz
url = 'https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/diabetes.csv'
df = pd.read_csv(url)

display(df.head())
print(f"\nQatorlar va ustunlar soni: {df.shape}")
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# Qatorlar va ustunlar soni: (768, 9)

# %% [markdown]
# #### Ustunlar ta'riflari
# * `Pregnancies` - homilador bo'lish soni
# * `Glucose` - glyukozaga test natijasi
# * `BloodPressure` -  diastolik qon bosimi (mm Hg)
# * `SkinThickness` - Triceps teri burmasining qalinligi (mm)
# * `Insulin` - 2 soatlik sarum insulini (mu U/ml)
# * `BMI` - Tana massasi indeksi (vazn kg / (m bo'yi) ^ 2)
# * `DiabetesPedigreeFunction` - diabetning naslchilik funktsiyasi
# * `Age` - Yosh (yil)
# * `Outcome` - Class (0 - diabet yo'q, 1 - diabet)

# %% [markdown]
# ##### Outcome datasetda label (y) mo'ljal ustun, bu ustun `0` va `1` kategoriyalardan tashkil topgan

# %%
# dataset ustunlari haqida ma'lumot
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# raqamli ustunlar umimiy tahlili
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# NaN qiymatlar mavjudligini tekshirish
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# NaN qiymatlar mavjud emas

# %%
# Outcome ustun tahlili
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
#  Muvozanat buzilgan, kategoriyalar soni farqi katta. Bu holat modelni qo'pol xatolar qilishga va bir tomonga og'ishiga olib keladi
#  ##### Yechim:
#  `1` kategoriyali ma'lumotlarni yig'ish yoki `0` kategoriayali elementlarni sonini kamaytirish va tenglashtirish

# %% [markdown]
# #### Xossalar bir-biriga bogliqligini tekshirish

# %%
# Umumiy korrelyatsiya
correl_matrix = df.corr().abs()
correl_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e575c_row0_col0, #T_e575c_row1_col1, #T_e575c_row2_col2, #T_e575c_row3_col3, #T_e575c_row4_col4, #T_e575c_row5_col5, #T_e575c_row6_col6, #T_e575c_row7_col7, #T_e575c_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e575c_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_e575c_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e575c_row0_col3, #T_e575c_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e575c_row0_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e575c_row0_col5, #T_e575c_row0_col6, #T_e575c_row1_col3, #T_e575c_row2_col8, #T_e575c_row3_col1, #T_e575c_row5_col0, #T_e575c_row5_col7, #T_e575c_row6_col2, #T_e575c_row6_col7, #T_e575c_row7_col4, #T_e575c_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e575c_row0_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_e575c_row0_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e575c_row1_col0, #T_e575c_row1_col2, #T_e575c_row6_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e575c_row1_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e575c_row1_col5, #T_e575c_row8_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e575c_row1_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e575c_row1_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e575c_row1_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e575c_row2_col0, #T_e575c_row6_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e575c_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e575c_row2_col3, #T_e575c_row4_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e575c_row2_col4, #T_e575c_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e575c_row2_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e575c_row2_col6, #T_e575c_row3_col8, #T_e575c_row4_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e575c_row2_col7, #T_e575c_row8_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e575c_row3_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e575c_row3_col2, #T_e575c_row5_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e575c_row3_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_e575c_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_e575c_row3_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_e575c_row3_col7, #T_e575c_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e575c_row4_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e575c_row4_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e575c_row4_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e575c_row4_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_e575c_row4_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e575c_row5_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e575c_row5_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e575c_row5_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e575c_row5_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e575c_row5_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e575c_row6_col0, #T_e575c_row7_col5, #T_e575c_row8_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e575c_row6_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e575c_row6_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e575c_row7_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_e575c_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e575c_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_e575c_row7_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e575c_row7_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e575c_row8_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e575c_row8_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_e575c_row8_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_e575c_row8_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e575c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e575c_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_e575c_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_e575c_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_e575c_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_e575c_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_e575c_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_e575c_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_e575c_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_e575c_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e575c_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_e575c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e575c_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_e575c_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_e575c_row0_col3" class="data row0 col3" >0.081672</td>
#       <td id="T_e575c_row0_col4" class="data row0 col4" >0.073535</td>
#       <td id="T_e575c_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_e575c_row0_col6" class="data row0 col6" >0.033523</td>
#       <td id="T_e575c_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_e575c_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_e575c_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_e575c_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_e575c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e575c_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_e575c_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_e575c_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_e575c_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_e575c_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_e575c_row1_col7" class="data row1 col7" >0.263514</td>
#       <td id="T_e575c_row1_col8" class="data row1 col8" >0.466581</td>
#     </tr>
#     <tr>
#       <th id="T_e575c_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_e575c_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_e575c_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_e575c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e575c_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_e575c_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_e575c_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_e575c_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_e575c_row2_col7" class="data row2 col7" >0.239528</td>
#       <td id="T_e575c_row2_col8" class="data row2 col8" >0.065068</td>
#     </tr>
#     <tr>
#       <th id="T_e575c_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_e575c_row3_col0" class="data row3 col0" >0.081672</td>
#       <td id="T_e575c_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_e575c_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_e575c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e575c_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_e575c_row3_col5" class="data row3 col5" >0.392573</td>
#       <td id="T_e575c_row3_col6" class="data row3 col6" >0.183928</td>
#       <td id="T_e575c_row3_col7" class="data row3 col7" >0.113970</td>
#       <td id="T_e575c_row3_col8" class="data row3 col8" >0.074752</td>
#     </tr>
#     <tr>
#       <th id="T_e575c_level0_

# %%
# Barcha ustunlarning Outcome ustuni bilan korrelyatsiyasi
df.corrwith(df['Outcome']).sort_values(ascending=False)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# dtype: float64

# %% [markdown]
# Xulosa: `SkinThickness` va `BloodPressure` ustunlar korrelyatsiya juda past tashlab yuborish mumkin

# %% [markdown]
# ### 3-qadam. Ma'lumotlarni tahrirlash

# %%
# dataset ustunlari nomlarini tahrirlashga qulay ko'rinishga keltirish
column_names = df.columns
df.columns = column_names.str.lower()

# %%
# Outcome elementlarini tenglashtirish, 232ta 0 elemntlarni tashlab yuboramiz
idx = df[df['outcome']==0].sample(232).index
df.drop(idx, inplace=True)

# %%
# Outcome elementlar muvozanatini tekshirish
df['outcome'].value_counts()
# Out:
# outcome
# 1    268
# 0    268
# Name: count, dtype: int64

# %% [markdown]
# ### 4-qadam. Ma'lumotlarga ishlov berish

# %%
# Feature va traget, train va test qismlarga ajratish
X = df.drop('outcome', axis=1)
y = df['outcome'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=25)

# ma'lumotlarni normalizatsiya qilish
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### 5-qadam. Klassificator model yaratish

# %%
# model parametri uchun eng yaxshi k qiymatni ni topish
param_grid = {'n_neighbors':np.arange(1,25)}

knn_gscv = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5, scoring='accuracy')
knn_gscv.fit(X_train, y_train)
best_k = knn_gscv.best_params_['n_neighbors']
print('Eng yaxshi k qiymat:', best_k)
print('Eng yaxshi k qiymat accuracy score:', knn_gscv.best_score_.round(3))
# Out:
# Eng yaxshi k qiymat: 8
# Eng yaxshi k qiymat accuracy score: 0.732

# %%
# eng yaxshi k ni chizmada tasvirlash
plt.figure(figsize=(8,5))
plt.plot(range(1,25), knn_gscv.cv_results_['rank_test_score'])
plt.xticks(range(1,25))
plt.xlabel('k')
plt.ylabel('Xatoliklar reytingi')
plt.grid(linestyle=':')
plt.show()

# %%
# model yaratish va uni o'qitish
knn_model = KNeighborsClassifier(n_neighbors=best_k, weights='distance')

knn_model.fit(X_train_scaled, y_train)
prediction = knn_model.predict(X_test_scaled)

# %% [markdown]
# ### 6-qadam. Modelni baholash

# %%
# jaccard_score yordamida baholash
jac_score = jaccard_score(y_test, prediction).round(4)
print("Jaccard_score natija:", jac_score)
# Out:
# Jaccard_score natija: 0.7143

# %%
# confusion_matrics tahlili
matrix = confusion_matrix(y_test, prediction)
sns.heatmap(matrix, annot=True)
plt.show()

# %%
# precision, recall, accuracy va f1_score natijalarni qo'lda hisoblash
precision = precision_score(y_test, prediction)
recall = recall_score(y_test, prediction)
f1 = f1_score(y_test, prediction)
accuracy = accuracy_score(y_test, prediction)

print(f"{precision = } \n{recall = } \n{f1 = } \n{accuracy = }")
# Out:
# precision = 0.8620689655172413
# recall = 0.8064516129032258
# f1 = 0.8333333333333334
# accuracy = 0.8148148148148148

# %%
# cross_val_predict yordamida baholash
X_scaled = scaler.transform(X)
cv_predict = cross_val_predict(estimator=knn_model, X=X_scaled, y=y, cv=5)
print(classification_report(y, cv_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71       268
#            1       0.71      0.71      0.71       268
#
#     accuracy                           0.71       536
#    macro avg       0.71      0.71      0.71       536
# weighted avg       0.71      0.71      0.71       536

# %% [markdown]
# ### 7-qadam. Taqdimot
# Loyihani ishga tushirib, buyurtmachining fikr va mulohazalariga qarab loyihani taqdim qilish mumkin yoki ortga 2-qadamgacha qaytib, loyihani qayta ishlab chiqib, yuqoriroq natija bilan qayta taqdimot qilinadi. Loyiha talabga javob bersa topshiriladi
